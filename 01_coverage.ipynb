# %% [markdown]
# # Compare coverage between MetaMorpheus and Proteome Discoverer

# %%
import oscutils

# %%
oscutils.make_proteins_counts_plot(quant_or_found="quant", clean=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 oscutils.make_proteins_counts_plot(quant_or_found="quant", clean=False)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/oscutils/make_plots.py:38, in make_proteins_counts_plot(quant_or_found, clean)
#       8 def make_proteins_counts_plot(
#       9     quant_or_found: str,
#      10     clean: bool,
#      11 ) -> alt.Chart:
#      12     """
#      13     Generate a plot showing the count of proteins found for each sample,
#      14     including results for both the MetaMorpheus and the Proteome Discoverer
#    (...)
#      35         tool for each sample.
#      36     """
# ---> 38     df = _get_proteins_found_count(source="both", quant_or_found=quant_or_found, clean=clean)
#      40     if clean:
#      41
#      42         # Join the "sample_type" and "sample_condition" columns into a single column by which we'll color code the bars
#      43         df = df.assign(
#      44             sample_type_condition=(df["sample_type"] + "_" + df["sample_condition"].fillna("")).str.replace(r"_$", "", regex=True),
#      45         )
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/oscutils/load_data.py:276, in _get_proteins_found_count(source, quant_or_found, clean)
#     271 # If data from both MetaMorpheus and Proteome Discoverer are requested, recursively call this
#     272 # function to get the individual tables, add a column to specify which tool each count came
#     273 # from, and concatenate the tables
#     274 if source == "both":
# --> 276     df_mm = _get_proteins_found_count(source="mm", quant_or_found=quant_or_found, clean=clean).\
#     277     assign(software="mm")
#     279     df_pd = _get_proteins_found_count(source="pd", quant_or_found=quant_or_found, clean=clean).\
#     280     assign(software="pd")
#     282     df = pd.concat(
#     283         objs=[df_mm, df_pd],
#     284         axis="index",
#     285         join="outer",
#     286         ignore_index=True,
#     287     )
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/oscutils/load_data.py:296, in _get_proteins_found_count(source, quant_or_found, clean)
#     293     index_cols += ["contaminated", "no_protein"]
#     295 # Get the count of proteins found for each sample
# --> 296 df = load_protein_table(source=source, quant_or_found=quant_or_found, clean=clean).\
#     297 set_index(index_cols).\
#     298 notna().\
#     299 sum(axis=1).\
#     300 sort_values().\
#     301 to_frame().\
#     302 reset_index().\
#     303 rename(columns={0: "quant_proteins_count"})
#     305 # Replace the "contaminated" and "no_protein" tables with a single column called "status" that has
#     306 # a value of either "Normal", "Contaminated", "No Protein", or "Contaminated, No protein" for each
#     307 # sample
#     308 if not clean:
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/oscutils/load_data.py:43, in load_protein_table(source, quant_or_found, clean)
#      40 if quant_or_found == "found":
#      41     raise ValueError("'found' data not available from MetaMorpheus.")
# ---> 43 df = _load_original_table("mm", "AllQuantifiedProteinGroups") # Load protein table
#      44 ed = _load_original_table("mm", "ExperimentalDesign") # Load experimental design table
#      46 df = df.set_index("Protein Accession") # Index by protein accession
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/oscutils/load_data.py:239, in _load_original_table(source, name)
#     232     raise ValueError(f"Invalid argument '{source}' for source parameter.")
#     234 if source == "mm" and name == "AllQuantifiedProteinGroups":
#     235     # All the lines in the tsv for this table have an extra tab
#     236     # character at the end of every line except for the first one,
#     237     # which causes the headers to be read in offset by one column.
#     238     # This line addresses that.
# --> 239     df = pd.read_csv(file_path, sep="\t", usecols=range(136))
#     240 else:
#     241     df = pd.read_csv(file_path, sep="\t")
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1679, in TextFileReader._make_engine(self, f, engine)
#    1676     raise ValueError(msg)
#    1678 try:
# -> 1679     return mapping[engine](f, **self.options)
#    1680 except Exception:
#    1681     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:548, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/.pyenv/versions/3.10.11/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:781, in pandas._libs.parsers.TextReader._get_header()
#
# ValueError: Number of passed names did not match number of header fields in the file

# %%
oscutils.make_proteins_counts_plot(quant_or_found="quant", clean=True)
