# %% [markdown]
# # Compare coverage between MetaMorpheus and Proteome Discoverer

# %%
import oscutils

# %%
oscutils.make_proteins_counts_plot(quant_or_found="quant")
# Out:
# alt.FacetChart(...)
