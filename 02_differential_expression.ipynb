# %%
import oscutils

# %%
oscutils.load_protein_table("pd", "quant", clean=True)
# Out:
#                  sample sample_type sample_condition  sample_num  P04264
# 2      boost_healthy_01       boost          healthy           1     2.7  \
# 3      boost_healthy_02       boost          healthy           2     3.7
# 4      boost_healthy_03       boost          healthy           3     2.2
# 5    boost_unhealthy_01       boost        unhealthy           1     2.9
# 6    boost_unhealthy_02       boost        unhealthy           2     1.8
# 7    boost_unhealthy_03       boost        unhealthy           3     4.2
# 11      hfl1_healthy_04        hfl1          healthy           4    71.3
# 12      hfl1_healthy_06        hfl1          healthy           6    45.7
# 13      hfl1_healthy_07        hfl1          healthy           7    69.4
# 14      hfl1_healthy_08        hfl1          healthy           8   275.0
# 15      hfl1_healthy_09        hfl1          healthy           9   448.2
# 16      hfl1_healthy_10        hfl1          healthy          10    73.5
# ...
